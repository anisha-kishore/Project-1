# %%
import pandas as pd
from pathlib import Path

# %%
injury_file = Path("Resources/injury_data.csv")
injury_df = pd.read_csv(injury_file)
injury_df.head()
# Out:
#   Playerid Height  Weight   Season Side Body Part Part Specific  Injury Type  \
# 0  Player1   6'9"     225  2005-06  NaN      head           jaw     fracture
# 1  Player1   6'9"     225  2006-07  NaN       NaN           NaN      illness
# 2  Player1   6'9"     225  2006-07    R      knee           NaN     soreness
# 3  Player1   6'9"     225  2007-08    R      knee           NaN     effusion
# 4  Player1   6'9"     225  2007-08    R      knee           NaN  debridement
#
#   Surgery?    Time of Year  Total  Regular Season Games Missed  \
# 0      Yes  Regular season                                10.0
# 1       No  Regular season                                 1.0
# 2       No  Regular season                                 1.0
# 3       No  Regular season                                10.0
# 4      Yes  Regular season                                65.0
#
#    Total Playoff Games Missed
# 0                           0
# 1                           0
# ...
